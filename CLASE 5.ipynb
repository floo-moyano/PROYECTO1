# %%
import pandas as pd 
df = pd.read_csv('datos.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-2-792993bed8b6> in <module>()
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('datos.csv')
#
# C:\Anaconda\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
df = pd.read_csv('datos.csv', error_bad_lines=False, sep=";") #leyendo una serie de datos, transformandolo en una tabla llamada data frame (df)

# %%
df
# Out:
#             comunasubida      comunabajada mediahora viaje_laboral_promedio  \
# 0                  MAIPU                15  15:30:00              19,286888
# 1                     38                35  12:00:00                4,91385
# 2          QUINTA NORMAL                41  12:30:00               2,343198
# 3                     38      SAN BERNARDO  19:30:00              24,991406
# 4                     38                 5  15:00:00       43,6520420000001
# 5                     35             NUNOA  06:30:00               6,062386
# 6               CONCHALI      SAN BERNARDO  12:30:00               1,610436
# 7               LA REINA         QUILICURA  12:00:00               1,576984
# 8          QUINTA NORMAL          LA REINA  19:30:00               1,094366
# 9                  RENCA  ESTACION CENTRAL  05:30:00              24,398536
# 10      ESTACION CENTRAL                27  11:00:00                0,78542
# ...

# %%
#Hacer un función que me dice si un string es valido o no

def valido(x):
    try:
        int(x)
        return False
    except:
        return True

# %%
valido('x')
# Out:
# True

# %%
valido('1') #si logro transformar esto en un numero, entonces es valido, si no, no
# Out:
# False

# %%
df.comunabajada.apply(valido) #aplicando la funcion a cada valor, toma cada valor y lo va pasando a una función (apply)
# Out:
# 0         False
# 1         False
# 2         False
# 3          True
# 4         False
# 5          True
# 6          True
# 7          True
# 8          True
# 9          True
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17         True
# 18         True
# 19         True
# 20        False
# 21         True
# 22         True
# 23         True
# 24         True
# 25         True
# 26         True
# 27         True
# 28        False
# 29         True
#           ...
# 107872    False
# 107873    False
# 107874    False
# 107875     True
# 107876     True
# 107877    False
# 107878     True
# 107879    False
# 107880    False
# 107881     True
# 107882    False
# 107883     True
# 107884     True
# 107885     True
# 107886    False
# 107887     True
# 107888     True
# 107889     True
# 107890     True
# 107891    False
# 107892     True
# 107893     True
# 107894     True
# 107895     True
# ...

# %%
df[df.comunabajada.apply(valido)] #usando la función como filtro
# Out:
#             comunasubida         comunabajada mediahora  \
# 3                     38         SAN BERNARDO  19:30:00
# 5                     35                NUNOA  06:30:00
# 6               CONCHALI         SAN BERNARDO  12:30:00
# 7               LA REINA            QUILICURA  12:00:00
# 8          QUINTA NORMAL             LA REINA  19:30:00
# 9                  RENCA     ESTACION CENTRAL  05:30:00
# 17                     5                MACUL  19:30:00
# 18           CERRO NAVIA             SANTIAGO  10:00:00
# 19      ESTACION CENTRAL             SANTIAGO  10:30:00
# 21              SANTIAGO           HUECHURABA  05:00:00
# 22           PROVIDENCIA          CERRO NAVIA  11:30:00
# 23                 RENCA             LO PRADO  23:30:00
# 24                    15          LA CISTERNA  08:00:00
# 25                    34            PENALOLEN  12:00:00
# 26              LO PRADO            PENALOLEN  16:30:00
# 27                 RENCA            SAN RAMON  11:00:00
# ...

# %%
df[df.comunabajada.apply(valido)][df.comunasubida.apply(valido)]
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             comunasubida         comunabajada mediahora  \
# 6               CONCHALI         SAN BERNARDO  12:30:00
# 7               LA REINA            QUILICURA  12:00:00
# 8          QUINTA NORMAL             LA REINA  19:30:00
# 9                  RENCA     ESTACION CENTRAL  05:30:00
# 18           CERRO NAVIA             SANTIAGO  10:00:00
# 19      ESTACION CENTRAL             SANTIAGO  10:30:00
# 21              SANTIAGO           HUECHURABA  05:00:00
# 22           PROVIDENCIA          CERRO NAVIA  11:30:00
# 23                 RENCA             LO PRADO  23:30:00
# 26              LO PRADO            PENALOLEN  16:30:00
# 27                 RENCA            SAN RAMON  11:00:00
# 29             LA GRANJA            QUILICURA  10:30:00
# 30                 MACUL             PUDAHUEL  08:00:00
# ...

# %%
#Hacer un función que me dice si un string es valido o no

def valido(x):
    if x == '-':
        return False
    try:
        int(x)
        return False
    except:
        return True

# %%
df=df[df.comunabajada.apply(valido)][df.comunasubida.apply(valido)]
df
# Out:
#                comunasubida         comunabajada mediahora  \
# 6                  CONCHALI         SAN BERNARDO  12:30:00
# 7                  LA REINA            QUILICURA  12:00:00
# 8             QUINTA NORMAL             LA REINA  19:30:00
# 9                     RENCA     ESTACION CENTRAL  05:30:00
# 18              CERRO NAVIA             SANTIAGO  10:00:00
# 19         ESTACION CENTRAL             SANTIAGO  10:30:00
# 21                 SANTIAGO           HUECHURABA  05:00:00
# 22              PROVIDENCIA          CERRO NAVIA  11:30:00
# 23                    RENCA             LO PRADO  23:30:00
# 26                 LO PRADO            PENALOLEN  16:30:00
# 27                    RENCA            SAN RAMON  11:00:00
# 29                LA GRANJA            QUILICURA  10:30:00
# 30                    MACUL             PUDAHUEL  08:00:00
# 33              LA CISTERNA          LA CISTERNA  20:00:00
# 35                LO ESPEJO            LA GRANJA  22:30:00
# ...

# %%
import geocoder
g=geocoder.komoot('LA REINA')
print(g.latlng)
# Out:
# [39.9611526, -4.830791]

# %%
for index, row in df.iterrows():
    print(row.comunabajada, "/", row.comunasubida)
# Out:
# SAN BERNARDO / CONCHALI
# QUILICURA / LA REINA
# LA REINA / QUINTA NORMAL
# ESTACION CENTRAL / RENCA
# SANTIAGO / CERRO NAVIA
# SANTIAGO / ESTACION CENTRAL
# HUECHURABA / SANTIAGO
# CERRO NAVIA / PROVIDENCIA
# LO PRADO / RENCA
# PENALOLEN / LO PRADO
# SAN RAMON / RENCA
# QUILICURA / LA GRANJA
# PUDAHUEL / MACUL
# LA CISTERNA / LA CISTERNA
# LA GRANJA / LO ESPEJO
# PEDRO AGUIRRE CERDA / INDEPENDENCIA
# ESTACION CENTRAL / SAN JOAQUIN
# SANTIAGO / RENCA
# LO PRADO / LO PRADO
# PROVIDENCIA / PROVIDENCIA
# PROVIDENCIA / VITACURA
# RENCA / SAN JOAQUIN
# PENALOLEN / INDEPENDENCIA
# PEDRO AGUIRRE CERDA / SANTIAGO
# LO PRADO / ESTACION CENTRAL
# QUINTA NORMAL / SAN RAMON
# CONCHALI / SAN MIGUEL
# CERRILLOS / SAN RAMON
# LA FLORIDA / LA CISTERNA
# LA REINA / CONCHALI
# CONCHALI / SAN BERNARDO
# LO ESPEJO / LA REINA
# ESTACION CENTRAL / ESTACION CENTRAL
# LA PINTANA / PENALOLEN
# MAIPU / EL BOSQUE
# MACUL / LO BARNECHEA
# SAN RAMON / SAN MIGUEL
# SAN BERNARDO / SANTIAGO
# ...

# %%
import folium
mymap=folium.Map()
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def geocodificar(comuna):
    texto = comuna + ", Santiago, Chile"
    x = geocodes.get(texto, '')
    if x == '':
        x = geocoder.komoot(texto).latlng
        geocodes[texto] = x
    return x

# %%
p1 = geocoder.komoot('LA REINA, Chile').latlng
p2 = geocoder.komoot('MAIPU, Chile').latlng
points = [p1, p2]
mymap = folium.Map(location=p1)
folium.PolyLine(points, color='red', weight=2.5).add_to(mymap)
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
len(df)
# Out:
# 45290

# %%
mymap = folium.Map(location=p1)

for index, row in df.iterrows():
    comuna1 = row.comunasubida
    comuna2 = row.comunabajada
    p1 = geocoder.komoot(comuna1).latlng
    p2 = geocoder.komoot(comuna2).latlng
    points = [p1,p2]
    folium.PolyLine(points, color='red', wright=2.5).add_to(mymap)
    if index > 100:
        break
    print(index)
mymap
# Out:
# 6
# 7
# 8
# 9
# 18
# 19
# 21
# 22
# 23
# 26
# 27
# 29
# 30
# 33
# 35
# 38
# 40
# 41
# 43
# 46
# 48
# 49
# 52
# 53
# 57
# 60
# 61
# 64
# 65
# 68
# 69
# 70
# 71
# 74
# 75
# 78
# 82
# 84
# 86
# 88
# 90
# 92
# 93
# 96
# 97
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
geocodes = {}

# %%
def geocodificar(comuna):
    texto = comuna + ", Santiago, Chile"
    x = geocodes.get(texto, '')
    if x == '':
        x = geocoder.komoot(texto).latlng
        geocodes[texto] = x
    return x

# %%
mymap = folium.Map(location=p1)

for index, row in df.iterrows():
    comuna1 = row.comunasubida
    comuna2 = row.comunabajada
    p1 = geocodificar(comuna1)
    p2 = geocodificar(comuna2)
    points = [p1,p2]
    folium.PolyLine(points, color='red', wright=2.5).add_to(mymap)
    if index > 1000:
        break
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
